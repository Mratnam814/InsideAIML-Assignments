# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/loan.csv.crdownload")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
cat_col=[fea for fea in df.columns if df[fea].dtype=="O"]

# %%
num_col=[fea for fea in df.columns if df[fea].dtype != "O"]

# %%
cat_col
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
num_col
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
df=df.fillna({'ApplicantIncome':0,
 'CoapplicantIncome':0,
 'LoanAmount':0,
 'Loan_Amount_Term':0,
 'Credit_History':0,
  'Dependents':0,
              "Gender":'Not_Known',"Married":'Not_Known',"Self_Employed":'Not_Known'})

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         0.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
cat_col
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
df.head(1)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         0.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y

# %%
df['Education']=label_encoder.fit_transform(df['Education']) #grad:0 ,non-grad:1

# %%
df.head(1)
# Out:
#     Loan_ID Gender Married Dependents  Education Self_Employed  \
# 0  LP001002   Male      No          0          0            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         0.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
df['Property_Area']=label_encoder.fit_transform(df['Property_Area'])

# %%
df['Property_Area'].value_counts() #su-1 ,U-2 , R-3
# Out:
# 1    233
# 2    202
# 0    179
# Name: Property_Area, dtype: int64

# %%
df['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
df['Loan_Status']=label_encoder.fit_transform(df['Loan_Status'])
df['Self_Employed']=label_encoder.fit_transform(df['Self_Employed'])

# %%
df['Loan_Status'].value_counts() #Y-1 ,N-0
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %%
df.head(2)
# Out:
#     Loan_ID Gender Married Dependents  Education  Self_Employed  \
# 0  LP001002   Male      No          0          0              0
# 1  LP001003   Male     Yes          1          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         0.0             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0

# %%
df=df.replace('3+',3)

# %%
X=df.iloc[:,3:12]

# %%
X
# Out:
#     Dependents  Education  Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0            0          0              0             5849                0.0
# 1            1          0              0             4583             1508.0
# 2            0          0              2             3000                0.0
# 3            0          1              0             2583             2358.0
# 4            0          0              0             6000                0.0
# ..         ...        ...            ...              ...                ...
# 609          0          0              0             2900                0.0
# 610          3          0              0             4106                0.0
# 611          1          0              0             8072              240.0
# 612          2          0              0             7583                0.0
# 613          0          0              2             4583                0.0
#
# ...

# %%
y=df['Loan_Status']

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
ordered_rank_features=SelectKBest(score_func=chi2,k='all')
ordered_feature=ordered_rank_features.fit(X,y)

# %%
dfscores=pd.DataFrame(ordered_feature.scores_,columns=["Score"])
dfcolumns=pd.DataFrame(X.columns)

# %%
features_rank=pd.concat([dfcolumns,dfscores],axis=1)

# %%
features_rank.columns=['Features','Score']
features_rank
# Out:
#             Features         Score
# 0         Dependents      0.085953
# 1          Education      3.540502
# 2      Self_Employed      0.001995
# 3    ApplicantIncome     93.904964
# 4  CoapplicantIncome  11342.041603
# 5         LoanAmount      3.829885
# 6   Loan_Amount_Term      0.661295
# 7     Credit_History     26.014804
# 8      Property_Area      0.377837

# %%
features_rank.nlargest(10,'Score')
# Out:
#             Features         Score
# 4  CoapplicantIncome  11342.041603
# 3    ApplicantIncome     93.904964
# 7     Credit_History     26.014804
# 5         LoanAmount      3.829885
# 1          Education      3.540502
# 6   Loan_Amount_Term      0.661295
# 8      Property_Area      0.377837
# 0         Dependents      0.085953
# 2      Self_Employed      0.001995
